# %%
# %pylab inline
import numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def listafrac(M,N):
    
    lista = []
    caras = []
    sellos = []
        
    for j in range (M):#recorre el numero de muestras 
        car=0.0
        
        for i in range (N): #recorre  el numero  de  lanzamientos por muestras 
            x=np.random.randint(2)
            if  (x==1):
                car=car+1 # suma si  es cara
        lista.append(car/N)
        caras.append(car)
        sell=N-car
        sellos.append(sell)
        
    return lista, caras, sellos

# %%
lista, caras, sellos =listafrac(20,1000)
print listafrac(20,1000)
print len(lista), len(caras), len(sellos)
# Out:
# ([0.48, 0.472, 0.49, 0.483, 0.512, 0.491, 0.508, 0.497, 0.498, 0.505, 0.508, 0.503, 0.475, 0.502, 0.479, 0.483, 0.499, 0.516, 0.528, 0.463], [480.0, 472.0, 490.0, 483.0, 512.0, 491.0, 508.0, 497.0, 498.0, 505.0, 508.0, 503.0, 475.0, 502.0, 479.0, 483.0, 499.0, 516.0, 528.0, 463.0], [520.0, 528.0, 510.0, 517.0, 488.0, 509.0, 492.0, 503.0, 502.0, 495.0, 492.0, 497.0, 525.0, 498.0, 521.0, 517.0, 501.0, 484.0, 472.0, 537.0])
# 20 20 20

# %%
des = std(lista)
pro = mean(lista)
print "desviacion estandar=", std(lista), " Promedio = ", mean(lista)
# Out:
# desviacion estandar= 0.0163348553713  Promedio =  0.49635

# %%
x1=pro-des
x2=pro+des
y1=pro-(2*des)
y2=pro+(2*des)
z1=pro-(3*des)
z2=pro+(3*des)

datos = hist(lista, bins=10)
axvline(x1, c='y')
axvline(x2, c='y')
axvline(y1, c='r')
axvline(y2, c='r')
axvline(z1,c='g')
axvline(z2,c='g')

# %%
# Tarea  2 / graf  1
#donde M numero de muestras, i= numero de lanzamientos que varia , M2=
#i = 1000
#M2 = 20000
def resta(M,i, M2):
    datosplo = []
    ejex=[]
    while i <= M2: 
        x ,y , z= listafrac(M, i)
        y_m = mean(y)
        z_m = mean(z) 
        dato=abs(y_m-z_m)
        datosplo.append(dato)
        ejex.append(i)
        i=i+1000
    return ejex, datosplo

# %%
x1, y1=resta(20, 1000, 20000)
x2, y2=resta(40, 1000, 20000)
scatter(x1 , y1, s=20, c='r')
scatter(x2 , y2, s=20, c='G', marker='^')

# %%
#fracion caras/sellos
def fraccion(M,i, M2):
    datosplo = []
    ejex=[]
    while i <= M2: 
        x ,y , z= listafrac(M, i)
        y_m = mean(y)
        z_m = mean(z) 
        dato=(y_m/z_m)
        datosplo.append(dato)
        ejex.append(i)
        i=i+1000
    return ejex, datosplo

# %%
x1, y1=fraccion(20, 1000, 20000)
x2, y2=fraccion(40, 1000, 20000)
scatter(x1 , y1, s=20, c='r')
scatter(x2 , y2, s=20, c='G', marker='^')

# %%
# Punto 2
x1, y1=resta(20, 1000, 20000)
x2, y2=resta(40, 1000, 20000)
scatter(x1 , y1, s=30, c='g')
scatter(x2 , y2, s=30, c='r', marker='^')
yscale("log")
title("Grafica en escala logaritmica de la resta de las medias \n caras/sellos para 20 y 40 muestras", fontsize=15)
xlabel("Numero de lanzamientos", fontsize=15)
ylabel("Diferencia de las medias cara/sello ", fontsize=15)

# %%
x1, y1=fraccion(20, 1000, 20000)
x2, y2=fraccion(40, 1000, 20000)
scatter(x1 , y1, s=20, c='r')
scatter(x2 , y2, s=20, c='G', marker='^')
yscale("log")

title("Grafica en escala logaritmica de la fraccion de las medias \n caras/sellos para 20 y 40 muestras", fontsize=15)
xlabel("Numero de lanzamientos", fontsize=15)
ylabel("Fraccion de las medias cara/sello ", fontsize=15)

# %%
#Punto 3
def restadesv(M,i, M2):
    datosplo = []
    ejex=[]
    while i <= M2: 
        x ,y , z= listafrac(M, i)
        y_m = std(y)
        z_m = std(z) 
        dato=abs(y_m-z_m)
        datosplo.append(dato)
        ejex.append(i)
        i=i+1000
    return ejex, datosplo

# %%
x1, y1=restadesv(20, 1000, 20000)
x2, y2=restadesv(40, 1000, 20000)
scatter(x1 , y1, s=30, c='g')
scatter(x2 , y2, s=30, c='r', marker='^')
title("Grafica de la resta de la desviacion estandar \n caras-sellos para 20 y 40 muestras", fontsize=15)
xlabel("Numero de lanzamientos", fontsize=15)
ylabel("Diferencia de las desviaciones estandar cara/sello ", fontsize=15)

# %%
def fracciondesv(M,i, M2):
    datosplo = []
    ejex=[]
    while i <= M2: 
        x ,y , z= listafrac(M, i)
        y_m = std(y)
        z_m = std(z) 
        dato=(y_m/z_m)
        datosplo.append(dato)
        ejex.append(i)
        i=i+1000
    return ejex, datosplo

# %%
x1, y1=fracciondesv(20, 1000, 20000)
x2, y2=fracciondesv(40, 1000, 20000)
scatter(x1 , y1, s=20, c='r')
scatter(x2 , y2, s=20, c='G', marker='^')

title("Grafica de la fraccion de las desviaciones estandar \n caras/sellos para 20 y 40 muestras", fontsize=15)
xlabel("Numero de lanzamientos", fontsize=15)
ylabel("Fraccion de desviaciones \n estandar cara/sello ", fontsize=15)

# %%
#correc del 1re punto
def restacor(M,i, M2):
    datosplo = []
    ejex=[]
    while i <= M2: 
        x ,y , z= listafrac(M, i)      
        
        for j in range(len(y)):
           dato=abs(y[j]-z[j])
           datosplo.append(dato)
           ejex.append(i)
           i=i+1
        
    return ejex, datosplo

# %%
h1, h1= restacor(20, 1000, 20000)
j2, j2= restacor(40, 1000, 20000)
scatter(x1 , y1, s=20, c='r')
scatter(x2 , y2, s=20, c='G', marker='^')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-1d8919622682> in <module>()
# ----> 1 h1, h1= restacor(20, 1000, 20000)
#       2 j2, j2= restacor(40, 1000, 20000)
#       3 scatter(x1 , y1, s=20, c='r')
#       4 scatter(x2 , y2, s=20, c='G', marker='^')
#
# <ipython-input-42-e2adcc73bc09> in restacor(M, i, M2)
#       4     ejex=[]
#       5     while i <= M2:
# ----> 6         x ,y , z= listafrac(M, i)
#       7
#       8         for j in range(len(y)):
#
# <ipython-input-22-d1bf16e23ef6> in listafrac(M, N)
#       8         car=0.0
#       9
# ---> 10         for i in range (N): #recorre  el numero  de  lanzamientos por muestras
#      11             x=np.random.randint(2)
#      12             if  (x==1):
#
# KeyboardInterrupt:

# %%
# tenego problemas con la resta y divicion ya que estas se dan de numeros de sumas pero tengo que sacarlos cada uno por aparte. 

def fraccioncorr(M,i, M2):
    datosplo = []
    ejex=[]
    while i <= M2: 
        x ,y , z= listafrac(M, i)
        dato=(y/z)
        datosplo.append(dato)
        ejex.append(i)
        i=i+1000
    return ejex, datosplo

# %%
x1, y1=fraccioncorr(20, 1000, 20000)
x2, y2=fraccioncorr(40, 1000, 20000)
scatter(x1 , y1, s=20, c='r')
scatter(x2 , y2, s=20, c='G', marker='^')
